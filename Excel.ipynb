# %%
# !pip install pandas pymongo
# Out:
# Requirement already satisfied: pandas in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: pymongo in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (4.7.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from pymongo) (2.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (3.1.3)
# Requirement already satisfied: et-xmlfile in c:\users\veera\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd

# Load the Excel file
excel_file_path = r"C:\Users\veera\OneDrive\Desktop\Database\telugu_test.xlsx"
df = pd.read_excel(excel_file_path)

# Display the DataFrame to verify
print(df.head())
# Out:
#      Telugu_Words
# 0  స్మార్ట్‌ఫోన్‌
# 1           ఉన్నత
# 2        తగ్గించే
# 3             వేళ
# 4         కార్డ్‌

# %%
from pymongo import MongoClient

# Replace with your MongoDB connection details
client = MongoClient('mongodb+srv://ssurinen:IZlBWgTOHA4l3KX4@sathvikteja.jjzuamj.mongodb.net/')
db = client['excel']

# %%
collection = db['new']

# %%
# Convert DataFrame to a list of dictionaries
data = df.to_dict(orient='records')
records = df.to_dict(orient='records')
for i, record in enumerate(records, start=1):
    record['_id'] = i

db.new.insert_many(records)
print("Data inserted successfully!")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[6], line 7
#       4 for i, record in enumerate(records, start=1):
#       5     record['_id'] = i
# ----> 7 db.new.insert_many(records)
#       8 print("Data inserted successfully!")
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\collection.py:742, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     740 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     741 blk.ops = list(gen())
# --> 742 blk.execute(write_concern, session, _Op.INSERT)
#     743 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\bulk.py:595, in _Bulk.execute(self, write_concern, session, operation)
#     593         return None
#     594 else:
# --> 595     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\bulk.py:452, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     441     self._execute_command(
#     442         generator,
#     443         write_concern,
#    (...)
#     448         full_result,
#     449     )
#     451 client = self.collection.database.client
# --> 452 client._retryable_write(
#     453     self.is_retryable,
#     454     retryable_bulk,
#     455     session,
#     456     operation,
#     457     bulk=self,
#     458     operation_id=op_id,
#     459 )
#     461 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     462     _raise_bulk_write_error(full_result)
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1569, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1555 """Execute an operation with consecutive retries if possible
#    1556
#    1557 Returns func()'s return value on success. On error retries the same
#    (...)
#    1566 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1567 """
#    1568 with self._tmp_session(session) as s:
# -> 1569     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1455, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1450 # Ensure that the options supports retry_writes and there is a valid session not in
#    1451 # transaction, otherwise, we will not support retry behavior for this txn.
#    1452 retryable = bool(
#    1453     retryable and self.options.retry_writes and session and not session.in_transaction
#    1454 )
# -> 1455 return self._retry_internal(
#    1456     func=func,
#    1457     session=session,
#    1458     bulk=bulk,
#    1459     operation=operation,
#    1460     retryable=retryable,
#    1461     operation_id=operation_id,
#    1462 )
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:2450, in _ClientConnectionRetryable._write(self)
#    2448 max_wire_version = 0
#    2449 is_mongos = False
# -> 2450 self._server = self._get_server()
#    2451 with self._client._checkout(self._server, self._session) as conn:
#    2452     max_wire_version = conn.max_wire_version
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:2433, in _ClientConnectionRetryable._get_server(self)
#    2428 def _get_server(self) -> Server:
#    2429     """Retrieves a server object based on provided object context
#    2430
#    2431     :return: Abstraction to connect to server
#    2432     """
# -> 2433     return self._client._select_server(
#    2434         self._server_selector,
#    2435         self._session,
#    2436         self._operation,
#    2437         address=self._address,
#    2438         deprioritized_servers=self._deprioritized_servers,
#    2439         operation_id=self._operation_id,
#    2440     )
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1316, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1314             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1315     else:
# -> 1316         server = topology.select_server(
#    1317             server_selector,
#    1318             operation,
#    1319             deprioritized_servers=deprioritized_servers,
#    1320             operation_id=operation_id,
#    1321         )
#    1322     return server
#    1323 except PyMongoError as exc:
#    1324     # Server selection errors in a transaction are transient.
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:369, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     359 def select_server(
#     360     self,
#     361     selector: Callable[[Selection], Selection],
#    (...)
#     366     operation_id: Optional[int] = None,
#     367 ) -> Server:
#     368     """Like select_servers, but choose a random server if several match."""
# --> 369     server = self._select_server(
#     370         selector,
#     371         operation,
#     372         server_selection_timeout,
#     373         address,
#     374         deprioritized_servers,
#     375         operation_id=operation_id,
#     376     )
#     377     if _csot.get_timeout():
#     378         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:347, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     338 def _select_server(
#     339     self,
#     340     selector: Callable[[Selection], Selection],
#    (...)
#     345     operation_id: Optional[int] = None,
#     346 ) -> Server:
# --> 347     servers = self.select_servers(
#     348         selector, operation, server_selection_timeout, address, operation_id
#     349     )
#     350     servers = _filter_servers(servers, deprioritized_servers)
#     351     if len(servers) == 1:
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:254, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     251     server_timeout = server_selection_timeout
#     253 with self._lock:
# --> 254     server_descriptions = self._select_servers_loop(
#     255         selector, server_timeout, operation, operation_id, address
#     256     )
#     258     return [
#     259         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     260     ]
#
# File c:\Users\veera\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:304, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     293     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     294         _debug_log(
#     295             _SERVER_SELECTION_LOGGER,
#     296             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     302             failure=self._error_message(selector),
#     303         )
# --> 304     raise ServerSelectionTimeoutError(
#     305         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     306     )
#     308 if not logged_waiting:
#     309     _info_log(
#     310         _SERVER_SELECTION_LOGGER,
#     311         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     317         remainingTimeMS=int(end_time - time.monotonic()),
#     318     )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-koqdrbm-shard-00-02.jjzuamj.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-koqdrbm-shard-00-00.jjzuamj.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-koqdrbm-shard-00-01.jjzuamj.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6659934829602605eda218da, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-koqdrbm-shard-00-00.jjzuamj.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-koqdrbm-shard-00-00.jjzuamj.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-koqdrbm-shard-00-01.jjzuamj.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-koqdrbm-shard-00-01.jjzuamj.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-koqdrbm-shard-00-02.jjzuamj.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-koqdrbm-shard-00-02.jjzuamj.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>]>

# %%
# Out:
# InsertManyResult([ObjectId('665813a2bb952d5cbeb0752f'), ObjectId('665813a2bb952d5cbeb07530'), ObjectId('665813a2bb952d5cbeb07531'), ObjectId('665813a2bb952d5cbeb07532'), ObjectId('665813a2bb952d5cbeb07533'), ObjectId('665813a2bb952d5cbeb07534'), ObjectId('665813a2bb952d5cbeb07535'), ObjectId('665813a2bb952d5cbeb07536'), ObjectId('665813a2bb952d5cbeb07537'), ObjectId('665813a2bb952d5cbeb07538'), ObjectId('665813a2bb952d5cbeb07539'), ObjectId('665813a2bb952d5cbeb0753a'), ObjectId('665813a2bb952d5cbeb0753b'), ObjectId('665813a2bb952d5cbeb0753c'), ObjectId('665813a2bb952d5cbeb0753d'), ObjectId('665813a2bb952d5cbeb0753e'), ObjectId('665813a2bb952d5cbeb0753f'), ObjectId('665813a2bb952d5cbeb07540'), ObjectId('665813a2bb952d5cbeb07541'), ObjectId('665813a2bb952d5cbeb07542'), ObjectId('665813a2bb952d5cbeb07543'), ObjectId('665813a2bb952d5cbeb07544'), ObjectId('665813a2bb952d5cbeb07545'), ObjectId('665813a2bb952d5cbeb07546'), ObjectId('665813a2bb952d5cbeb07547'), ObjectId('665813a2b